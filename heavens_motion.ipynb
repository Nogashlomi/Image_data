# %%
import pandas as pd 
import glob
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path_to_xlsx = 'G:\\My Drive\\DataFiles\\Full_Image_List_6.5.24\\all_elements_with_part_type.xlsx'

# %%
all_elements_full_info = pd.read_excel(path_to_xlsx)

# %%
path_to_csv = 'G:\\My Drive\\DataFiles\\booksSacrobosco.csv'

# %%
all_books = pd.read_csv(path_to_csv)

# %%
daily_motion = all_elements_full_info[all_elements_full_info['keywords'].str.contains('CK_Daily Rotation of the Firmament')]

# Define the 20-year intervals
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals in water_earth
daily_motion['year_interval'] = pd.cut(daily_motion['year'], bins=bins, labels=labels, right=True)

# Group by year_interval and part_type, and count unique images
grouped = daily_motion.groupby(['year_interval', 'part_type'], observed=True)['images'].nunique().reset_index()

# Pivot the table for easier plotting
pivot_df = grouped.pivot(index='year_interval', columns='part_type', values='images').fillna(0)

# Create a new column 'year_interval' in all_books
all_books['year_interval'] = pd.cut(all_books['year_published_from'], bins=bins, labels=labels, right=True)

# Group by year_interval and count unique subjects
grouped_subjects = all_books.groupby('year_interval', observed=True)['subject'].nunique().reset_index()

# Plot the data
plt.figure(figsize=(12, 6))

# Plot unique images for each part_type
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

# Plot unique subjects
plt.plot(grouped_subjects['year_interval'], grouped_subjects['subject'], marker='o', linestyle='--', color='black', label='Toal Printed Books in the Corpus')

plt.title('Daily Rotation of the Heavens Images (over time, by part type')
plt.xlabel('Year Interval')
plt.ylabel('Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\619541375.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_motion['year_interval'] = pd.cut(daily_motion['year'], bins=bins, labels=labels, right=True)

# %%
# Define the DataFrame filtering for the specific keyword
daily_motion = all_elements_full_info[all_elements_full_info['keywords'].str.contains('CK_Daily Rotation of the Firmament')]

# Define the 20-year intervals
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals in daily_motion
daily_motion['year_interval'] = pd.cut(daily_motion['year'], bins=bins, labels=labels, right=True)

# Group by year_interval and part_type, and count unique images
grouped = daily_motion.groupby(['year_interval', 'part_type'], observed=True)['images'].nunique().reset_index()

# Pivot the table for easier plotting
pivot_df = grouped.pivot(index='year_interval', columns='part_type', values='images').fillna(0)

# Calculate total unique images for each year_interval
total_unique_images = daily_motion.groupby('year_interval', observed=True)['images'].nunique().reset_index()
total_unique_images = total_unique_images.rename(columns={'images': 'total_images'})

# Create a new column 'year_interval' in all_books
all_books['year_interval'] = pd.cut(all_books['year_published_from'], bins=bins, labels=labels, right=True)

# Group by year_interval and count unique subjects
grouped_subjects = all_books.groupby('year_interval', observed=True)['subject'].nunique().reset_index()

# Plot the data
plt.figure(figsize=(12, 6))

# Plot unique images for each part_type
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

# Plot unique subjects
plt.plot(grouped_subjects['year_interval'], grouped_subjects['subject'], marker='o', linestyle='--', color='black', label='Total Printed Books in the Corpus')

# Plot total unique images
plt.plot(total_unique_images['year_interval'], total_unique_images['total_images'], marker='s', linestyle='-', color='red', label='Total Unique Images')

plt.title('Daily Rotation of the Heavens Images (over time, by part type)')
plt.xlabel('Year Interval')
plt.ylabel('Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\3333780513.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_motion['year_interval'] = pd.cut(daily_motion['year'], bins=bins, labels=labels, right=True)

# %%
motion_eighth_sphere = all_elements_full_info[all_elements_full_info['keywords'].str.contains('CK_Motion of the Eighth Sphere')]

# Define the 20-year intervals
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals in water_earth
motion_eighth_sphere['year_interval'] = pd.cut(motion_eighth_sphere['year'], bins=bins, labels=labels, right=True)

# Group by year_interval and part_type, and count unique images
grouped = motion_eighth_sphere.groupby(['year_interval', 'part_type'], observed=True)['images'].nunique().reset_index()

# Pivot the table for easier plotting
pivot_df = grouped.pivot(index='year_interval', columns='part_type', values='images').fillna(0)

# Create a new column 'year_interval' in all_books
all_books['year_interval'] = pd.cut(all_books['year_published_from'], bins=bins, labels=labels, right=True)

# Group by year_interval and count unique subjects
grouped_subjects = all_books.groupby('year_interval', observed=True)['subject'].nunique().reset_index()

# Plot the data
plt.figure(figsize=(12, 6))

# Plot unique images for each part_type
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

# Plot unique subjects
plt.plot(grouped_subjects['year_interval'], grouped_subjects['subject'], marker='o', linestyle='--', color='black', label='Toal Printed Books in the Corpus')

plt.title('Motion of the Eighth Sphere')
plt.xlabel('Year Interval')
plt.ylabel('Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\3129578009.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   motion_eighth_sphere['year_interval'] = pd.cut(motion_eighth_sphere['year'], bins=bins, labels=labels, right=True)

# %%
# Define the 20-year intervals
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column 'year_interval' to hold the 20-year intervals in motion_eighth_sphere
motion_eighth_sphere['year_interval'] = pd.cut(motion_eighth_sphere['year'], bins=bins, labels=labels, right=True)

# Group by year_interval and part_type, and count unique images
grouped = motion_eighth_sphere.groupby(['year_interval', 'part_type'], observed=True)['images'].nunique().reset_index()

# Pivot the table for easier plotting
pivot_df = grouped.pivot(index='year_interval', columns='part_type', values='images').fillna(0)

# Calculate total unique images for each year_interval
total_unique_images = motion_eighth_sphere.groupby('year_interval', observed=True)['images'].nunique().reset_index()
total_unique_images = total_unique_images.rename(columns={'images': 'total_images'})

# Create a new column 'year_interval' in all_books
all_books['year_interval'] = pd.cut(all_books['year_published_from'], bins=bins, labels=labels, right=True)

# Group by year_interval and count unique subjects
grouped_subjects = all_books.groupby('year_interval', observed=True)['subject'].nunique().reset_index()

# Plot the data
plt.figure(figsize=(12, 6))

# Plot unique images for each part_type
for part_type in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[part_type], marker='o', label=f'Part Type {part_type}')

# Plot unique subjects
plt.plot(grouped_subjects['year_interval'], grouped_subjects['subject'], marker='o', linestyle='--', color='black', label='Total Printed Books in the Corpus')

# Plot total unique images
plt.plot(total_unique_images['year_interval'], total_unique_images['total_images'], marker='s', linestyle='-', color='red', label='Total Unique Images')

plt.title('Motion of the Eighth Sphere')
plt.xlabel('Year Interval')
plt.ylabel('Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\191343007.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   motion_eighth_sphere['year_interval'] = pd.cut(motion_eighth_sphere['year'], bins=bins, labels=labels, right=True)

# %%
path_to_xlsx_visual_data = 'C:\\Users\\nogas\\Image_data\\daily_motion_clusters.xlsx'

# %%
visual_data = pd.read_excel(path_to_xlsx_visual_data)

# %%
# Merge the DataFrames on 'common_column'
daily_motion_visual = pd.merge(daily_motion, visual_data, on='cluster_name')

# %%
daily_motion_visual
# Out:
#                                                 images  \
# 0    http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 1    http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 2    http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 3    http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 4    http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# ..                                                 ...
# 224  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 225  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 226  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 227  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
# 228  http://devmeta.sphaera.mpiwg-berlin.mpg.de/res...
#
#                                               keywords cluster_name  \
# 0    SK_1.5 Their movements;CK_Daily Rotation of th...    SIL_00163
# 1    SK_1.6 Revolution of the heavens from east to ...    SIL_01163
# 2    SK_1.6 Revolution of the heavens from east to ...    SIL_00531
# 3    SK_1.6 Revolution of the heavens from east to ...    SIL_00531
# 4    SK_1.6 Revolution of the heavens from east to ...    SIL_00531
# ..                                                 ...          ...
# 224  CK_Daily Rotation of the Firmament;MVK_Pictori...    SIL_02501
# 225  MVK_Pictorial_Diagrams;MTK_Daily Rotation of t...    SIL_01995
# 226  CK_Daily Rotation of the Firmament;MVK_Pictori...    SIL_02234
# 227  SK_1.6 Revolution of the heavens from east to ...    SIL_01507
# 228  SK_1.5 Their movements;CK_Daily Rotation of th...    SIL_01647
#
#                                                authors  \
# 0                              Sacrobosco, Johannes de
# 1             Sacrobosco, Johannes de;Borro, Gasparino
# 2                              Sacrobosco, Johannes de
# 3                              Sacrobosco, Johannes de
# 4                              Sacrobosco, Johannes de
# ..                                                 ...
# 224                                       Nunes, Pedro
# 225                                       Nunes, Pedro
# 226                                       Hill, Thomas
# 227  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
# 228  Sacrobosco, Johannes de;Vinet, Élie;Hero, Albe...
#
#                       publishers                     printers      place  \
# 0              Landsberg, Martin            Landsberg, Martin    Leipzig
# 1            Scoto I., Ottaviano            Locatello, Boneto     Venice
# 2              Landsberg, Martin            Landsberg, Martin    Leipzig
# 3              Stöckel, Wolfgang            Stöckel, Wolfgang    Leipzig
# 4              Landsberg, Martin            Landsberg, Martin    Leipzig
# ..                           ...                          ...        ...
# 224  Anonymous_SineLoco_[1526]_S  Anonymous_SineLoco_[1526]_S  Sine loco
# 225  Anonymous_SineLoco_[1526]_S  Anonymous_SineLoco_[1526]_S  Sine loco
# 226             Jaggard, William               Judson, Thomas     London
# 227                Bellère, Jean                Bellère, Jean    Antwerp
# 228                Bellère, Jean                Bellère, Jean    Antwerp
#
#      year   bid                                               book  ...  \
# 0    1486  1616  http://sphaera.mpiwg-berlin.mpg.de/id/item/c14...  ...
# 1    1494  1622  http://sphaera.mpiwg-berlin.mpg.de/id/item/b8e...  ...
# 2    1494  1626  http://sphaera.mpiwg-berlin.mpg.de/id/item/b63...  ...
# 3    1498  1632  http://sphaera.mpiwg-berlin.mpg.de/id/item/3ba...  ...
# 4    1498  1638  http://sphaera.mpiwg-berlin.mpg.de/id/item/52f...  ...
# ..    ...   ...                                                ...  ...
# 224  1521  2265  http://sphaera.mpiwg-berlin.mpg.de/id/item/fcd...  ...
# 225  1521  2265  http://sphaera.mpiwg-berlin.mpg.de/id/item/fcd...  ...
# 226  1599  2279  http://sphaera.mpiwg-berlin.mpg.de/id/item/e70...  ...
# 227  1582  2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...  ...
# 228  1582  2281  http://sphaera.mpiwg-berlin.mpg.de/id/item/af4...  ...
#
#     year_interval  2D/3D multiple moments full/partial circle human figures  \
# 0       1470-1489     2D               no                full            no
# 1       1490-1509     2D              yes         semi-circle            no
# 2       1490-1509     2D               no                full            no
# 3       1490-1509     2D               no                full            no
# 4       1490-1509     2D               no                full            no
# ..            ...    ...              ...                 ...           ...
# 224     1510-1529     3D              yes         semi-circle            no
# 225     1510-1529     3D               no                full           yes
# 226     1590-1609     3D              yes                full           yes
# 227     1570-1589     3D              yes                full           yes
# 228     1570-1589     3D               no                full           yes
#
#     line/ color refraction explanation double image material object diagram
# 0          line                     no           no              no      no
# 1         color                     no           no              no      no
# 2          line                     no           no              no      no
# 3          line                     no           no              no      no
# 4          line                     no           no              no      no
# ..          ...                    ...          ...             ...     ...
# 224        line                     no           no              no      no
# 225        line                     no           no              no      no
# 226        line                     no           no              no      no
# 227        line                     no           no              no      no
# 228        line                     no           no              no      no
#
# [229 rows x 24 columns]

# %%
# Assuming your DataFrame is named `daily_motion_visual` and is already loaded
# daily_motion_visual = pd.read_csv('your_file.csv')  # Load your data if needed

# Define the intervals and labels
bins = [1470, 1490, 1510, 1530, 1550, 1570, 1590, 1610, 1630, 1650]
labels = ['1470-1489', '1490-1509', '1510-1529', '1530-1549', '1550-1569', '1570-1589', '1590-1609', '1610-1629', '1630-1649']

# Create a new column for the 20-year intervals
daily_motion_visual['interval'] = pd.cut(daily_motion_visual['year'], bins=bins, labels=labels, right=False)

# Define the columns of interest and the specific unique values to plot
columns_of_interest = {
    '2D/3D': '3D',
    'multiple moments': 'yes',
    'full/partial circle': 'semi-circle',
    'full/partial circle': 'full',
    'human figures': 'human figures',
    'line/ color': 'color',
    'material object': 'material object',
    'diagram': 'diagram'
}

# Prepare a dictionary to hold the results
results = {}

# Calculate occurrences of the specified unique values for each interval
for column, value in columns_of_interest.items():
    if isinstance(value, list):
        # If value is a list, count occurrences of any of the values in the list
        results[column] = daily_motion_visual[daily_motion_visual[column].isin(value)].groupby('interval')['images'].nunique()
    else:
        # Otherwise, count occurrences of the single specified value
        results[column] = daily_motion_visual[daily_motion_visual[column] == value].groupby('interval')['images'].nunique()

# Calculate the total number of unique images per interval
total_unique_images = daily_motion_visual.groupby('interval')['images'].nunique()

# Convert the results dictionary to a DataFrame for easier plotting
results_df = pd.DataFrame(results)

# Add the total unique images to the DataFrame
results_df['total_unique_images'] = total_unique_images

# Define labels for the plot
plot_labels = {
    '2D/3D': '3D',
    'multiple moments': 'multiple moments',
    'full/partial circle': 'Semi-circle',
    'full/partial circle': 'full circle',
    'human figures': 'human figures',
    'line/ color': 'Color',
    'material object': 'material object',
    'diagram': 'diagram'
}

# Plotting
plt.figure(figsize=(12, 8))

# Plot each column of interest
for column, label in plot_labels.items():
    plt.plot(results_df.index, results_df[column], marker='o', label=label)

# Plot total unique images
plt.plot(results_df.index, results_df['total_unique_images'], marker='o', linestyle='--', label='Total Unique Images')

# Adding titles and labels
plt.title('Visual Aspects of Daily Motion Images')
plt.xlabel('Year')
plt.ylabel('Number of Unique Images')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\392176132.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   results[column] = daily_motion_visual[daily_motion_visual[column] == value].groupby('interval')['images'].nunique()
# C:\Users\nogas\AppData\Local\Temp\ipykernel_17388\392176132.py:36: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_unique_images = daily_motion_visual.groupby('interval')['images'].nunique()
